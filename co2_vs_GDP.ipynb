# %%
import pandas as pd
import matplotlib.pyplot as plt
import wbgapi as wb

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2022-04-08
# 3     Worldwide Governance Indicators                                       WGI              3  2021-09-27
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-01-14
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
emission = wb.data.DataFrame('EN.ATM.CO2E.KT', wb.region.members('EMU'))
emission
# Out:
#              YR1960      YR1961      YR1962      YR1963      YR1964  \
# economy
# AUT       30821.135   31862.563   33905.082   36992.696   38943.540
# BEL       91000.272   92793.435   98117.919  105781.949  103662.423
# CYP         887.414     865.412     905.749     986.423    1001.091
# DEU             NaN         NaN         NaN         NaN         NaN
# ESP       48928.781   53677.546   60054.459   58822.347   64410.855
# EST             NaN         NaN         NaN         NaN         NaN
# FIN       15104.373   14939.358   16809.528   19358.093   22852.744
# FRA      271218.654  281211.229  298706.486  334019.696  345303.055
# GRC        9405.855    9823.893   10164.924   12258.781   13223.202
# IRL       11180.683   12365.124   13120.526   13461.557   14231.627
# ITA      109357.274  124549.655  146456.313  164780.312  175957.328
# LTU             NaN         NaN         NaN         NaN         NaN
# LUX       11518.047   11591.387   11551.050   11448.374   12306.452
# ...

# %%
ren = wb.data.DataFrame('EN.ATM.CO2E.KT',
                      ['DEU','FRA','ESP','GBR','USA'],
                      time=range(2000,2020,1))

# %%
ren
# Out:
#             YR2000     YR2001     YR2002     YR2003     YR2004     YR2005  \
# economy
# DEU       830080.0   847500.0   833180.0   836550.0   820830.0   802170.0
# ESP       293310.0   294790.0   312750.0   318660.0   335560.0   350500.0
# FRA       373240.0   376860.0   371170.0   376840.0   377950.0   380820.0
# GBR       530120.0   544480.0   530230.0   542080.0   542320.0   540600.0
# USA      5776410.0  5749250.0  5594160.0  5659630.0  5740030.0  5756080.0
#
#             YR2006     YR2007     YR2008     YR2009     YR2010     YR2011  \
# economy
# DEU       814160.0   783600.0   789550.0   734660.0   772920.0   746380.0
# ESP       341780.0   354680.0   324160.0   287490.0   273250.0   274400.0
# FRA       371600.0   362910.0   358210.0   343880.0   347940.0   333530.0
# GBR       541640.0   529160.0   514410.0   465120.0   481790.0   444420.0
# USA      5656580.0  5740270.0  5563340.0  5159550.0  5392870.0  5172100.0
#
# ...

# %%
ren.describe()
# Out:
#              YR2000        YR2001        YR2002        YR2003        YR2004  \
# count  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# mean   1.560632e+06  1.562576e+06  1.528298e+06  1.546752e+06  1.563338e+06
# std    2.365610e+06  2.349963e+06  2.281834e+06  2.307944e+06  2.342602e+06
# min    2.933100e+05  2.947900e+05  3.127500e+05  3.186600e+05  3.355600e+05
# 25%    3.732400e+05  3.768600e+05  3.711700e+05  3.768400e+05  3.779500e+05
# 50%    5.301200e+05  5.444800e+05  5.302300e+05  5.420800e+05  5.423200e+05
# 75%    8.300800e+05  8.475000e+05  8.331800e+05  8.365500e+05  8.208300e+05
# max    5.776410e+06  5.749250e+06  5.594160e+06  5.659630e+06  5.740030e+06
#
#              YR2005        YR2006        YR2007        YR2008        YR2009  \
# count  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# mean   1.566034e+06  1.545152e+06  1.554124e+06  1.509934e+06  1.398140e+06
# ...

# %%
gdp= wb.data.DataFrame('NY.GDP.MKTP.CD',
                      ['DEU','FRA','ESP','GBR','USA'],
                      time=range(2000,2020,1))

# %%
gdp
# Out:
#                YR2000        YR2001        YR2002        YR2003        YR2004  \
# economy
# DEU      1.943145e+12  1.944107e+12  2.068624e+12  2.496129e+12  2.809188e+12
# ESP      5.968776e+11  6.272868e+11  7.053943e+11  9.054921e+11  1.067093e+12
# FRA      1.362249e+12  1.376465e+12  1.494287e+12  1.840481e+12  2.115742e+12
# GBR      1.662127e+12  1.643908e+12  1.784077e+12  2.057094e+12  2.421814e+12
# USA      1.025235e+13  1.058182e+13  1.093642e+13  1.145824e+13  1.221373e+13
#
#                YR2005        YR2006        YR2007        YR2008        YR2009  \
# economy
# DEU      2.845803e+12  2.992197e+12  3.421229e+12  3.730028e+12  3.397791e+12
# ESP      1.153286e+12  1.259344e+12  1.472131e+12  1.625225e+12  1.485583e+12
# FRA      2.196126e+12  2.318594e+12  2.657213e+12  2.918383e+12  2.690222e+12
# GBR      2.544829e+12  2.717060e+12  3.106182e+12  2.938882e+12  2.425798e+12
# USA      1.303664e+13  1.381461e+13  1.445186e+13  1.471284e+13  1.444893e+13
#
# ...

# %%
gdp.describe()
# Out:
#              YR2000        YR2001        YR2002        YR2003        YR2004  \
# count  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# mean   3.163349e+12  3.234718e+12  3.397760e+12  3.751488e+12  4.125513e+12
# std    3.994595e+12  4.136063e+12  4.244820e+12  4.347201e+12  4.567484e+12
# min    5.968776e+11  6.272868e+11  7.053943e+11  9.054921e+11  1.067093e+12
# 25%    1.362249e+12  1.376465e+12  1.494287e+12  1.840481e+12  2.115742e+12
# 50%    1.662127e+12  1.643908e+12  1.784077e+12  2.057094e+12  2.421814e+12
# 75%    1.943145e+12  1.944107e+12  2.068624e+12  2.496129e+12  2.809188e+12
# max    1.025235e+13  1.058182e+13  1.093642e+13  1.145824e+13  1.221373e+13
#
#              YR2005        YR2006        YR2007        YR2008        YR2009  \
# count  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# mean   4.355337e+12  4.620361e+12  5.021723e+12  5.185072e+12  4.889666e+12
# ...

# %%
ren.hist(bins=50, figsize=(20, 15))
plt.savefig('numeric_attributes.png')
plt.show()

# %%
gdp.hist(bins=50, figsize=(20, 15))
plt.savefig('numeric_attributes.png')
plt.show()

# %%
wb.data.DataFrame('EN.ATM.CO2E.KT',
                      ['DEU','FRA','ESP','GBR','USA'],
                      time=range(2000,2020,1)).T.plot();

# %%
 wb.data.DataFrame('NY.GDP.MKTP.CD',
                      ['DEU','FRA','ESP','GBR','USA'],
                      time=range(2000,2020,1)).T.plot();

# %%
indicator_ids=['EN.ATM.CO2E.KT','NY.GDP.MKTP.CD']
country_code=['DEU','FRA','ESP','GBR','USA']

# %%
my_dataframe=wb.data.DataFrame(indicator_ids,country_code,mrv=5)

# %%
my_dataframe
# Out:
#                               YR2016        YR2017        YR2018  \
# economy series
# DEU     EN.ATM.CO2E.KT  7.471500e+05  7.322000e+05  7.095400e+05
#         NY.GDP.MKTP.CD  3.467498e+12  3.681733e+12  3.975347e+12
# ESP     EN.ATM.CO2E.KT  2.470300e+05  2.634400e+05  2.583400e+05
#         NY.GDP.MKTP.CD  1.232076e+12  1.309297e+12  1.420300e+12
# FRA     EN.ATM.CO2E.KT  3.127100e+05  3.163600e+05  3.099600e+05
#         NY.GDP.MKTP.CD  2.471286e+12  2.588741e+12  2.789594e+12
# GBR     EN.ATM.CO2E.KT  3.788900e+05  3.663800e+05  3.588000e+05
#         NY.GDP.MKTP.CD  2.722852e+12  2.699017e+12  2.900791e+12
# USA     EN.ATM.CO2E.KT  4.888640e+06  4.813720e+06  4.981300e+06
#         NY.GDP.MKTP.CD  1.874508e+13  1.954298e+13  2.061186e+13
#
#                               YR2019        YR2020
# economy series
# DEU     EN.ATM.CO2E.KT           NaN           NaN
#         NY.GDP.MKTP.CD  3.888327e+12  3.846414e+12
# ESP     EN.ATM.CO2E.KT           NaN           NaN
# ...
